# %%
# WAVWFORM
import matplotlib.pyplot as plt
import librosa
import librosa.display
import sklearn

audio_path = 'audio_pro/Cat_Meow_2-Cat_Stevens-2034822903.wav'
x,sr = librosa.load(audio_path)

plt.figure(figsize=(14,5))
librosa.display.waveplot(x,sr=sr)
plt.show()   


#SPECTOGRAM

X = librosa.stft(x)
Xdb = librosa.amplitude_to_db(abs(X))                                           
plt.figure(figsize=(14,5))                                                                          
librosa.display.specshow(Xdb, sr=sr, x_axis='time', y_axis='hz')
plt.show()

#MFCC
plt.figure(figsize=(14,5))
mfccs = librosa.feature.mfcc(x, sr=sr)                                   
print(mfccs.shape)
librosa.display.specshow(mfccs, sr=sr, x_axis='time')
plt.show()

#LOG-MEL
mfccs = sklearn.preprocessing.scale(mfccs, axis=1)                     
print(mfccs.mean(axis=1))
print(mfccs.var(axis=1))
# Out:
# (20, 219)
# [ 1.3064032e-08  0.0000000e+00  5.1711790e-09  0.0000000e+00
#   0.0000000e+00 -1.7418708e-08 -1.0886693e-09  1.0886693e-08
#  -4.3546771e-09 -8.7093541e-09  5.4433463e-10  0.0000000e+00
#  -2.1773385e-09  0.0000000e+00 -2.1773385e-09  1.0886693e-08
#  -1.0886693e-08  0.0000000e+00  0.0000000e+00 -1.0886693e-08]
# [1.0000001  1.         1.0000001  0.9999997  1.0000001  1.
#  1.         1.0000001  1.         1.         1.0000001  1.
#  1.0000001  1.         1.         1.0000001  1.0000001  1.
#  1.         0.99999994]
# C:\Users\Dell\anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:174: UserWarning: Numerical issues were encountered when centering the data and might not be solved. Dataset may contain too large values. You may need to prescale your features.
#   warnings.warn("Numerical issues were encountered "
# C:\Users\Dell\anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:191: UserWarning: Numerical issues were encountered when scaling the data and might not be solved. The standard deviation of the data is probably very close to 0.
#   warnings.warn("Numerical issues were encountered "
